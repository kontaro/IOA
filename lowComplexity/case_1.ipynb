# %% [markdown]
# <a href="https://colab.research.google.com/github/kontaro/IOA/blob/main/lowComplexity/case_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AMPL  created by ChatGPT
# [![christmas.ipynb](https://img.shields.io/badge/github-%23121011.svg?logo=github)](https://github.com/kontaro/IOA/tree/main)
#
# Description: Christmas model generated by ChatGPT
#
# Tags: christmas, chatgpt, amplpy, highlights
#
# Notebook author: Mauricio Moyano <<mauricio.moyano@pucv.cl>>
#
# Model author: [ChatGPT](https://chat.openai.com/)
